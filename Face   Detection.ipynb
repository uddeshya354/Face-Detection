#   inflating: data/labels/images.db5513fc-3bd9-11f0-9f9c-30d042133894.json
#   inflating: data/labels/images.dc89f7ef-3bd9-11f0-92f9-30d042133894.json
#   inflating: data/labels/images.ddbf0832-3bd9-11f0-88ef-30d042133894.json
#   inflating: data/labels/images.def3b1e2-3bd9-11f0-a4a2-30d042133894.json
#   inflating: data/labels/images.e02946d7-3bd9-11f0-8822-30d042133894.json
#   inflating: data/labels/images.e15e01d5-3bd9-11f0-8b45-30d042133894.json
#   inflating: data/labels/images.e292c914-3bd9-11f0-916c-30d042133894.json
#   inflating: data/labels/images.e3c79c49-3bd9-11f0-bb38-30d042133894.json
#   inflating: data/labels/images.e4fc280c-3bd9-11f0-9658-30d042133894.json
#   inflating: data/labels/images.e630e357-3bd9-11f0-8ee7-30d042133894.json
#   inflating: data/labels/images.e7654291-3bd9-11f0-b624-30d042133894.json
#   inflating: data/labels/images.e899d22f-3bd9-11f0-93df-30d042133894.json
#   inflating: data/labels/images.e9ce464c-3bd9-11f0-9734-30d042133894.json
#   inflating: data/labels/images.eb03702c-3bd9-11f0-9ac7-30d042133894.json
#   inflating: data/labels/images.ec38208b-3bd9-11f0-8bd4-30d042133894.json
#   inflating: data/labels/images.ed6cca71-3bd9-11f0-856f-30d042133894.json
#   inflating: data/labels/images.f3742ec3-3bd9-11f0-ab05-30d042133894.json
#   inflating: data/labels/images.f4a8c9f0-3bd9-11f0-bd01-30d042133894.json
#   inflating: data/labels/images.f5dcb8bc-3bd9-11f0-8a2e-30d042133894.json
#   inflating: data/labels/images.f7118cfc-3bd9-11f0-908c-30d042133894.json
#   inflating: data/labels/images.f84608f8-3bd9-11f0-b093-30d042133894.json
#   inflating: data/labels/images.f97a7a47-3bd9-11f0-a75d-30d042133894.json
#   inflating: data/labels/images.faaf37df-3bd9-11f0-82da-30d042133894.json
#   inflating: data/labels/images.fbe2cd16-3bd9-11f0-8afc-30d042133894.json
#   inflating: data/labels/images.fd197a61-3bd9-11f0-84d5-30d042133894.json
#   inflating: data/labels/images.fe4e666e-3bd9-11f0-ab99-30d042133894.json
#   inflating: data/labels/images.ff83994b-3bd9-11f0-bf76-30d042133894.json

# %%
IMAGES_PATH_train = os.path.join('data','train')
IMAGES_PATH_test = os.path.join('data','test')
IMAGES_PATH_val = os.path.join('data','val')

for folder in ['images', 'labels']:

  os.makedirs(os.path.join(IMAGES_PATH_train, folder), exist_ok=True)
  os.makedirs(os.path.join(IMAGES_PATH_test, folder), exist_ok=True)
  os.makedirs(os.path.join(IMAGES_PATH_val, folder), exist_ok=True)

# %%
import os

# Define the base directory
BASE_DIR = 'aug_data'

# Define subfolders
folders = ['train', 'val', 'test']
subfolders = ['images', 'labels']

# Create the base directory and subfolders
for folder in folders:
  for subfolder in subfolders:
   path = os.path.join(BASE_DIR, folder)
   final_path = os.path.join(path,subfolder)
   os.makedirs(final_path, exist_ok=True)  # Create directories, ignoring if they already exist

# %%
import random
import shutil

for folder in [train,test,val]
source_dir = 'data/images'
target_images_dir = 'data/folder/images'

all_files = os.listdir(source_dir)
image_files = [f for f in all_files if f.lower().endswith(('.jpg', '.jpeg', '.png'))]

for imgnum in [63,13,14]:
  img_num = imgnum

# Randomly select 63 image files
  selected_images = random.sample(image_files, img_num)

    # Move the selected images to the destination directory
    print(f"Moving {image_num} random images from {source_dir} to {target_images_dir}...")
    for image in selected_images:
        source_path = os.path.join(source_dir, image)
        target_path = os.path.join(target_images_dir, image)
        shutil.move(source_path, destination_path)

    print("Image moving process completed.")
# Out:
# Moving 10 random images from data/images to data/train/images...
# Image moving process completed.

# %%
# !labelme
# Out:
# /bin/bash: line 1: labelme: command not found

# %% [markdown]
# # 2. Building Pipeline And Load Image

# %% [markdown]
# ### 2.1 Importing Dependencies

# %%
import tensorflow as tf
import json
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ### 2.3 Load Image into TF Data Pipeline

# %%
# !unzip "data.zip"
# Out:
# Archive:  data.zip
#    creating: data/
#    creating: data/images/
#    creating: data/images/.ipynb_checkpoints/
#   inflating: data/images/images.7547e2ba-3b8d-11f0-9f8e-30d042133894.jpg
#   inflating: data/images/images.7697be92-3b8d-11f0-ac01-30d042133894.jpg
#   inflating: data/images/images.77cc111c-3b8d-11f0-a79d-30d042133894.jpg
#   inflating: data/images/images.790088c2-3b8d-11f0-a544-30d042133894.jpg
#   inflating: data/images/images.7a34cf19-3b8d-11f0-ba0c-30d042133894.jpg
#   inflating: data/images/images.7b67cd49-3b8d-11f0-9356-30d042133894.jpg
#   inflating: data/images/images.7c9bf3ef-3b8d-11f0-8113-30d042133894.jpg
#   inflating: data/images/images.7dd02b91-3b8d-11f0-a3bd-30d042133894.jpg
#   inflating: data/images/images.7f04a71d-3b8d-11f0-a478-30d042133894.jpg
#   inflating: data/images/images.8038d618-3b8d-11f0-8ecc-30d042133894.jpg
#   inflating: data/images/images.816e09d2-3b8d-11f0-87dd-30d042133894.jpg
#   inflating: data/images/images.82a229da-3b8d-11f0-a7a4-30d042133894.jpg
#   inflating: data/images/images.83d6a400-3b8d-11f0-975a-30d042133894.jpg
#   inflating: data/images/images.850b3b47-3b8d-11f0-a8fa-30d042133894.jpg
#   inflating: data/images/images.863f78bb-3b8d-11f0-a99c-30d042133894.jpg
#   inflating: data/images/images.8773d381-3b8d-11f0-ab53-30d042133894.jpg
#   inflating: data/images/images.88a83e48-3b8d-11f0-bd99-30d042133894.jpg
#   inflating: data/images/images.89dcbef4-3b8d-11f0-828d-30d042133894.jpg
#   inflating: data/images/images.8b112b46-3b8d-11f0-a740-30d042133894.jpg
#   inflating: data/images/images.8c45b700-3b8d-11f0-bbb4-30d042133894.jpg
#   inflating: data/images/images.8d79e073-3b8d-11f0-a118-30d042133894.jpg
#   inflating: data/images/images.8eae8787-3b8d-11f0-ac1b-30d042133894.jpg
#   inflating: data/images/images.8fe2a283-3b8d-11f0-b4b1-30d042133894.jpg
#   inflating: data/images/images.9116f475-3b8d-11f0-bd0e-30d042133894.jpg
#   inflating: data/images/images.924b703a-3b8d-11f0-9f88-30d042133894.jpg
#   inflating: data/images/images.9380202e-3b8d-11f0-a5b3-30d042133894.jpg
#   inflating: data/images/images.bc79e120-3b8d-11f0-b819-30d042133894.jpg
#   inflating: data/images/images.bd6450f6-3b89-11f0-9af3-30d042133894.jpg
#   inflating: data/images/images.be98f432-3b89-11f0-98b6-30d042133894.jpg
#   inflating: data/images/images.bfcd6c15-3b89-11f0-ade0-30d042133894.jpg
#   inflating: data/images/images.c102056f-3b89-11f0-8cdd-30d042133894.jpg
#   inflating: data/images/images.c23670a3-3b89-11f0-9f70-30d042133894.jpg
#   inflating: data/images/images.c36adf60-3b89-11f0-aa47-30d042133894.jpg
#   inflating: data/images/images.c4a1d85a-3b89-11f0-b9a5-30d042133894.jpg
#   inflating: data/images/images.c5d53d36-3b89-11f0-a313-30d042133894.jpg
#   inflating: data/images/images.c709bfa4-3b89-11f0-a2c1-30d042133894.jpg
#   inflating: data/images/images.c83edbd9-3b89-11f0-872a-30d042133894.jpg
#   inflating: data/images/images.c97335e7-3b89-11f0-8416-30d042133894.jpg
#   inflating: data/images/images.caa7be28-3b89-11f0-a2a4-30d042133894.jpg
#   inflating: data/images/images.cbdb9bb7-3b89-11f0-955b-30d042133894.jpg
#   inflating: data/images/images.cd10e97b-3b89-11f0-9a3f-30d042133894.jpg
#   inflating: data/images/images.ce458a29-3b89-11f0-8c35-30d042133894.jpg
#   inflating: data/images/images.cf7a29aa-3b89-11f0-b252-30d042133894.jpg
#   inflating: data/images/images.d0aea006-3b89-11f0-9b6c-30d042133894.jpg
#   inflating: data/images/images.d1e305cb-3b89-11f0-948d-30d042133894.jpg
#   inflating: data/images/images.d3179f33-3b89-11f0-8335-30d042133894.jpg
#   inflating: data/images/images.d44c88ef-3b89-11f0-aae0-30d042133894.jpg
#   inflating: data/images/images.d580d68e-3b89-11f0-8700-30d042133894.jpg
#   inflating: data/images/images.d6b5813d-3b89-11f0-9762-30d042133894.jpg
#   inflating: data/images/images.d7ea1a67-3b89-11f0-82a8-30d042133894.jpg
#   inflating: data/images/images.d91f64f2-3b89-11f0-bf9b-30d042133894.jpg
#   inflating: data/images/images.da53a910-3b89-11f0-b40a-30d042133894.jpg
#   inflating: data/images/images.db881ace-3b89-11f0-bf6f-30d042133894.jpg
#   inflating: data/images/images.dcbca0b8-3b89-11f0-ab46-30d042133894.jpg
#    creating: data/test/
#    creating: data/train/
#    creating: data/val/

# %%
def load_image(x):
    byte_img = tf.io.read_file(x)
    img = tf.io.decode_jpeg(byte_img)
    return img

# %%
90*.7 # 63 to train

# %%
90*.15 # 14 and 13 to test and val

# %% [markdown]
# ### 3 Move the Matching Labels

# %%
import os
for folder in ['train','test','val']:
    for file in os.listdir(os.path.join('data', folder, 'images')):

        filename = file.split('.')[0]+'.'+file.split('.')[1]+'.json'
        existing_filepath = os.path.join('data','labels', filename)
        if os.path.exists(existing_filepath):
            new_filepath = os.path.join('data',folder,'labels',filename)
            os.replace(existing_filepath, new_filepath)

# %%
file = "image1.xyz.jpg"
file.split('.')
print(file.split('.')[0]+'.'+file.split('.')[1]+'.json')
# Out:
# image1.xyz.json

# %% [markdown]
# # 4. Image Augmentation on Images and Label it using Albumentations

# %% [markdown]
# ### 4.1 Setup Albumentations Transform Pipeline

# %%
import albumentations as alb
# Out:
# /usr/local/lib/python3.11/dist-packages/albumentations/__init__.py:28: UserWarning: A new version of Albumentations is available: '2.0.8' (you have '2.0.7'). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()

# %%
augmentor = alb.Compose([alb.RandomCrop(width=450, height=450),
                         alb.HorizontalFlip(p=0.5),
                         alb.RandomBrightnessContrast(p=0.2),
                         alb.RandomGamma(p=0.2),
                         alb.RGBShift(p=0.2),
                         alb.VerticalFlip(p=0.5)],
                       bbox_params=alb.BboxParams(format='albumentations',
                                                  label_fields=['class_labels']))

# %% [markdown]
# ### 4.2 Load a Test Image and Annotation with OpenCV and JSON

# %%
img = cv2.imread(os.path.join('data','train', 'images','10e686d8-a40e-11ef-a0ed-18473da52c96.jpg'))

# %%
try:
  with open(os.path.join('data', 'train', 'labels', '10e686d8-a40e-11ef-a0ed-18473da52c96.json'), 'r') as f:
    label = json.load(f)

except json.JSONDecodeError:
    print("Error: The JSON file is corrupted.")
except FileNotFoundError:
    print("Error: The file does not exist.")
# Out:
# Error: The file does not exist.

# %% [markdown]
# ### 4.3 Extract Coordinates and Rescale to Match Image Resolution

# %%
coords = [0,0,0,0]
coords[0] = label['shapes'][0]['points'][0][0]
coords[1] = label['shapes'][0]['points'][0][1]
coords[2] = label['shapes'][0]['points'][1][0]
coords[3] = label['shapes'][0]['points'][1][1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-0d6c1dfa2927> in <cell line: 0>()
#       1 coords = [0,0,0,0]
# ----> 2 coords[0] = label['shapes'][0]['points'][0][0]
#       3 coords[1] = label['shapes'][0]['points'][0][1]
#       4 coords[2] = label['shapes'][0]['points'][1][0]
#       5 coords[3] = label['shapes'][0]['points'][1][1]
#
# NameError: name 'label' is not defined

# %%
coords
# Out:
# [0, 0, 0, 0]

# %%
coords = np.divide(coords, [640,480,640,480])

# %%
coords
# Out:
# array([0.12268201, 0.01350733, 0.7888908 , 0.80677656])

# %% [markdown]
# ### 4.4 Apply Augmentations and View Results

# %%
augmented['bboxes']
tuple(np.multiply(augmented['bboxes'][0][:2], [450,450]).astype(int))
# Out:
# (155, 45)

# %%
cv2.rectangle(augmented['image'],
              tuple(np.multiply(augmented['bboxes'][0][:2], [450,450]).astype(int)),
              tuple(np.multiply(augmented['bboxes'][0][2:], [450,450]).astype(int)),
                    (255,0,0), 2)

plt.imshow(augmented['image'])

# %% [markdown]
# # 5. Build and Run Augmentation Pipeline

# %% [markdown]
# ### 5.1 Run Augmentation Pipeline

# %%
import os
import cv2
import json
import numpy as np
import albumentations as alb
from matplotlib import pyplot as plt

# Define the augmentation pipeline
augmentor = alb.Compose([alb.RandomCrop(width=450, height=450),
                         alb.HorizontalFlip(p=0.5),
                         alb.RandomBrightnessContrast(p=0.2),
                         alb.RandomGamma(p=0.2),
                         alb.RGBShift(p=0.2),
                         alb.VerticalFlip(p=0.5)],
                       bbox_params=alb.BboxParams(format='albumentations',
                                                  label_fields=['class_labels']))


for partition in ['train','test','val']:
    for image in os.listdir(os.path.join('data', partition, 'images')):
        img = cv2.imread(os.path.join('data', partition, 'images', image))

        coords = [0,0,0,0]
        # Construct the label path correctly, handling potential double extensions
        filename_parts = image.split('.')
        if len(filename_parts) > 2: # Handle cases like image.ext.jpg
            label_filename = '.'.join(filename_parts[:-1]) + '.json'
        else: # Handle cases like image.jpg
            label_filename = filename_parts[0] + '.json'

        label_path = os.path.join('data', partition, 'labels', label_filename)

        if os.path.exists(label_path):
            try:
                with open(label_path, 'r') as f:
                    label = json.load(f)

                # Extract coordinates only if shapes exist and have enough points
                if 'shapes' in label and len(label['shapes']) > 0 and len(label['shapes'][0]['points']) >= 2:
                    coords[0] = label['shapes'][0]['points'][0][0]
                    coords[1] = label['shapes'][0]['points'][0][1]
                    coords[2] = label['shapes'][0]['points'][1][0]
                    coords[3] = label['shapes'][0]['points'][1][1]
                    coords = list(np.divide(coords, [640,480,640,480])) # Assuming original image size is 640x480
                else:
                    # If no valid shapes, set coordinates to 0
                    coords = [0,0,0,0]
                    print(f"Warning: No valid shapes found in {label_path}. Setting bbox to [0,0,0,0].")

            except json.JSONDecodeError:
                print(f"Error: Corrupted JSON file: {label_path}")
                coords = [0,0,0,0] # Set coordinates to 0 if JSON is corrupted
            except Exception as e:
                print(f"An error occurred while reading {label_path}: {e}")
                coords = [0,0,0,0] # Set coordinates to 0 for other errors
        else:
            print(f"Warning: Label file not found for {image} at {label_path}. Setting bbox to [0,0,0,0].")
            coords = [0,0,0,0] # Set coordinates to 0 if label file doesn't exist


        try:
            for x in range(60):
                # Apply augmentation
                augmented = augmentor(image=img, bboxes=[coords] if coords != [0,0,0,0] else [], class_labels=['face'] if coords != [0,0,0,0] else []) # Pass bboxes and class_labels only if coords are not zero

                # Generate augmented image filename and save
                augmented_image_filename = f'{os.path.splitext(image)[0]}.{x}.jpg'
                cv2.imwrite(os.path.join('aug_data', partition, 'images', augmented_image_filename), augmented['image'])

                # Create annotation dictionary
                annotation = {}
                annotation['image'] = augmented_image_filename # Save the name of the augmented image

                # Populate annotation based on augmentation results
                if len(augmented['bboxes']) == 0:
                    annotation['bbox'] = [0,0,0,0]
                    annotation['class'] = 0
                else:
                    annotation['bbox'] = augmented['bboxes'][0]
                    annotation['class'] = 1

                # Generate augmented label filename and save
                augmented_label_filename = f'{os.path.splitext(image)[0]}.{x}.json'
                with open(os.path.join('aug_data', partition, 'labels', augmented_label_filename), 'w') as f:
                    json.dump(annotation, f)

        except Exception as e:
            print(f"An error occurred during augmentation for {image}: {e}")
# Out:
# Warning: Label file not found for images.cf4848e1-3bd9-11f0-b001-30d042133894.jpg at data/train/labels/images.cf4848e1-3bd9-11f0-b001-30d042133894.json. Setting bbox to [0,0,0,0].
# Warning: Label file not found for images.eea15751-3bd9-11f0-b71f-30d042133894.jpg at data/train/labels/images.eea15751-3bd9-11f0-b71f-30d042133894.json. Setting bbox to [0,0,0,0].
# Warning: Label file not found for images.f23fbd17-3bd9-11f0-8972-30d042133894.jpg at data/train/labels/images.f23fbd17-3bd9-11f0-8972-30d042133894.json. Setting bbox to [0,0,0,0].
# Warning: Label file not found for images.d07d592b-3bd9-11f0-b9e6-30d042133894.jpg at data/train/labels/images.d07d592b-3bd9-11f0-b9e6-30d042133894.json. Setting bbox to [0,0,0,0].
# Warning: Label file not found for images.f10adffc-3bd9-11f0-ae00-30d042133894.jpg at data/train/labels/images.f10adffc-3bd9-11f0-ae00-30d042133894.json. Setting bbox to [0,0,0,0].
# Warning: Label file not found for images.efd63ec1-3bd9-11f0-aefe-30d042133894.jpg at data/test/labels/images.efd63ec1-3bd9-11f0-aefe-30d042133894.json. Setting bbox to [0,0,0,0].

# %%
annotation

# %% [markdown]
# ### 5.2 Load Augmented Images to Tensorflow Dataset

# %%
import tensorflow as tf
file_path = 'aug_data/train/images/*.jpg'
train_images = tf.data.Dataset.list_files(file_path, shuffle=False)
train_images = train_images.map(load_image)
train_images = train_images.map(lambda x: tf.image.resize(x, (120,120)))
train_images = train_images.map(lambda x: x/255)

# %%
file_path = 'aug_data/test/images/*.jpg'
test_images = tf.data.Dataset.list_files(file_path, shuffle=False)
test_images = test_images.map(load_image)
test_images = test_images.map(lambda x: tf.image.resize(x, (120,120)))
test_images = test_images.map(lambda x: x/255)

# %%
file_path = 'aug_data/val/images/*.jpg'
val_images = tf.data.Dataset.list_files(file_path, shuffle=False)
val_images = val_images.map(load_image)
val_images = val_images.map(lambda x: tf.image.resize(x, (120,120)))
val_images = val_images.map(lambda x: x/255)

# %%
train_images.as_numpy_iterator().next()

# %% [markdown]
# # 6. Prepare Labels

# %% [markdown]
# ### 6.1 Build Label Loading Function

# %%
def load_labels(label_path):
    with open(label_path.numpy(), 'r', encoding = "utf-8") as f:
        label = json.load(f)

    return [label['class']], label['bbox']

# %% [markdown]
# ### 6.2 Load Labels to Tensorflow Dataset

# %%
import tensorflow as tf

# %%
file_path = 'aug_data/train/labels/*.json'
train_labels = tf.data.Dataset.list_files(file_path  , shuffle=False)
train_labels = train_labels.map(lambda x: tf.py_function(load_labels, [x], [tf.uint8, tf.float16]))

# %%
test_labels = tf.data.Dataset.list_files('aug_data/test/labels/*.json'  , shuffle=False)
test_labels = test_labels.map(lambda x: tf.py_function(load_labels, [x], [tf.uint8, tf.float16]))

# %%
val_labels = tf.data.Dataset.list_files('aug_data/test/labels/*.json', shuffle=False)
val_labels = val_labels.map(lambda x: tf.py_function(load_labels, [x], [tf.uint8, tf.float16]))

# %%
train_labels.as_numpy_iterator().next()
# Out:
# (array([0], dtype=uint8), array([0., 0., 0., 0.], dtype=float16))

# %% [markdown]
# # 7. Combine Label and Image Samples

# %% [markdown]
# ### 7.1 Check Partition Lengths

# %%
len(train_images), len(train_labels), len(test_images), len(test_labels), len(val_images), len(val_labels)
# Out:
# (3900, 3900, 840, 840, 780, 840)

# %% [markdown]
# ### 7.2 Create Final Datasets (Images/Labels)

# %%
train = tf.data.Dataset.zip((train_images, train_labels))
train = train.shuffle(5000)
train = train.batch(8)
train = train.prefetch(4)

# %%
test = tf.data.Dataset.zip((test_images, test_labels))
test = test.shuffle(1300)
test = test.batch(8)
test = test.prefetch(4)

# %%
val = tf.data.Dataset.zip((val_images, val_labels))
val = val.shuffle(1000)
val = val.batch(8)
val = val.prefetch(4)

# %%
train.as_numpy_iterator().next()
# Out:
# (array([[[[0.4935049 , 0.08235294, 0.04963235],
#           [0.48235294, 0.07843138, 0.05453431],
#           [0.48578432, 0.08970588, 0.05147059],
#           ...,
#           [0.40625   , 0.38125   , 0.29938725],
#           [0.40373775, 0.3803309 , 0.31629902],
#           [0.41881126, 0.39283088, 0.35251224]],
#
#          [[0.51029414, 0.08137255, 0.06262255],
#           [0.5054534 , 0.08192402, 0.07107843],
#           [0.48688725, 0.08094363, 0.06237745],
#           ...,
#           [0.44957107, 0.41433823, 0.34963235],
#           [0.4569853 , 0.42297795, 0.3872549 ],
#           [0.47175246, 0.46194854, 0.44123775]],
#
#          [[0.5246936 , 0.08302696, 0.07028186],
#           [0.5193015 , 0.08192402, 0.07898284],
#           [0.513174  , 0.08964461, 0.08137255],
#           ...,
#           [0.46133578, 0.4456495 , 0.40165442],
#           [0.47977942, 0.46709558, 0.44595587],
#           [0.58933824, 0.59405637, 0.57150733]],
#
#          ...,
#
#          [[0.75177693, 0.7596201 , 0.85765934],
#           [0.77003676, 0.7778799 , 0.8759191 ],
#           [0.7921569 , 0.79607844, 0.90588236],
#           ...,
#           [0.6798407 , 0.6798407 , 0.71121323],
#           [0.70484066, 0.7087622 , 0.7283701 ],
#           [0.72518384, 0.7291054 , 0.74871325]],
#
#          [[0.7613358 , 0.7766544 , 0.87469363],
#           [0.78180146, 0.7891544 , 0.8886642 ],
#           [0.7952206 , 0.7991422 , 0.9089461 ],
#           ...,
#           [0.6602941 , 0.66862744, 0.7142157 ],
#           [0.67444855, 0.6827819 , 0.7283701 ],
#           [0.69307595, 0.7026961 , 0.74405634]],
#
#          [[0.7658701 , 0.78155637, 0.8826593 ],
#           [0.7839461 , 0.80079657, 0.8917892 ],
#           [0.8148897 , 0.8188113 , 0.9286152 ],
#           ...,
#           [0.66243875, 0.6702819 , 0.71979165],
#           [0.6716912 , 0.6795343 , 0.72677696],
#           [0.68572307, 0.6944853 , 0.73878676]]],
#
#
#         [[[0.35036764, 0.04754902, 0.04276961],
#           [0.41942403, 0.07285539, 0.06452206],
#           [0.43167892, 0.0473652 , 0.03560049],
#           ...,
#           [0.49650735, 0.09258579, 0.0713848 ],
#           [0.5199755 , 0.12683824, 0.06605392],
#           [0.48431373, 0.16519608, 0.12346814]],
#
#          [[0.38492647, 0.0646446 , 0.04767157],
#           [0.40974265, 0.06317402, 0.04785539],
#           [0.42714462, 0.05643382, 0.03982843],
#           ...,
#           [0.51354164, 0.11482843, 0.09522059],
#           [0.52506125, 0.15827206, 0.12702206],
#           [0.40882352, 0.22193627, 0.19613971]],
#
#          [[0.37506127, 0.05692402, 0.03094363],
#           [0.41317403, 0.07015932, 0.04362745],
#           [0.42205882, 0.05735294, 0.02990196],
#           ...,
#           [0.49117646, 0.12303922, 0.10575981],
#           [0.49007353, 0.21213235, 0.19993873],
#           [0.4536152 , 0.40876225, 0.38474265]],
#
#          ...,
#
#          [[0.54313725, 0.54313725, 0.53786767],
#           [0.5446691 , 0.54025733, 0.5338848 ],
#           [0.5372549 , 0.5294118 , 0.53333336],
#           ...,
#           [0.55784315, 0.5617647 , 0.58137256],
#           [0.55441177, 0.55833334, 0.5779412 ],
#           [0.55128676, 0.5552083 , 0.57481617]],
#
#          [[0.5346201 , 0.5311887 , 0.549326  ],
#           [0.5411765 , 0.53333336, 0.5441176 ],
#           [0.5407475 , 0.5329044 , 0.53682595],
#           ...,
#           [0.5711397 , 0.5681985 , 0.5912377 ],
#           [0.5647672 , 0.5608456 , 0.58137256],
#           [0.56329656, 0.5559436 , 0.57555145]],
#
#          [[0.543076  , 0.53425246, 0.563174  ],
#           [0.5421569 , 0.53088236, 0.55735296],
#           [0.5539216 , 0.5411765 , 0.54509807],
#           ...,
#           [0.5615809 , 0.56911767, 0.59411764],
#           [0.56041664, 0.5613971 , 0.5790441 ],
#           [0.5529412 , 0.5484681 , 0.56237745]]],
#
#
#         [[[0.45667893, 0.45514706, 0.46758577],
#           [0.55269605, 0.5553309 , 0.563174  ],
#           [0.5526348 , 0.5604779 , 0.55655634],
#           ...,
#           [0.49001226, 0.47481617, 0.3949142 ],
#           [0.5067402 , 0.46991423, 0.38860294],
#           [0.5054534 , 0.45355392, 0.38596815]],
#
#          [[0.48682597, 0.4815564 , 0.49166667],
#           [0.54148287, 0.54148287, 0.54148287],
#           [0.54865193, 0.54865193, 0.54865193],
#           ...,
#           [0.4779412 , 0.47401962, 0.39166668],
#           [0.48241422, 0.47506127, 0.39227942],
#           [0.49797794, 0.45042893, 0.39393383]],
#
#          [[0.5373775 , 0.52953434, 0.5334559 ],
#           [0.5564951 , 0.54865193, 0.5525735 ],
#           [0.5617647 , 0.5539216 , 0.55784315],
#           ...,
#           [0.4822304 , 0.4598039 , 0.37346813],
#           [0.48670343, 0.4788603 , 0.39552698],
#           [0.48541668, 0.44509804, 0.3803309 ]],
#
#          ...,
#
#          [[0.54362744, 0.31574756, 0.2807598 ],
#           [0.60036767, 0.27892157, 0.27450982],
#           [0.6231618 , 0.21409313, 0.22745098],
#           ...,
#           [0.22481617, 0.10925245, 0.09362745],
#           [0.24001226, 0.10232843, 0.09362745],
#           [0.23572303, 0.10220588, 0.08455882]],
#
#          [[0.6482843 , 0.23400736, 0.20575981],
#           [0.6456495 , 0.2435049 , 0.2166054 ],
#           [0.656924  , 0.24522059, 0.23002452],
#           ...,
#           [0.21017157, 0.08860294, 0.0689951 ],
#           [0.23180147, 0.09454657, 0.07071079],
#           [0.23468137, 0.09834559, 0.07156863]],
#
#          [[0.6692402 , 0.23394608, 0.20631127],
#           [0.62126225, 0.23253676, 0.19221814],
#           [0.63057595, 0.22371323, 0.17579657],
#           ...,
#           [0.22720589, 0.10471813, 0.09718137],
#           [0.21305147, 0.0841299 , 0.07726716],
#           [0.22628677, 0.10073529, 0.07530637]]],
#
#
#         ...,
#
#
#         [[[0.70140934, 0.67879903, 0.6238971 ],
#           [0.70257354, 0.6834559 , 0.62352943],
#           [0.71213233, 0.7029412 , 0.6320466 ],
#           ...,
#           [0.7043505 , 0.69797796, 0.7175858 ],
#           [0.6839461 , 0.6759804 , 0.7248162 ],
#           [0.68737745, 0.67855394, 0.74191177]],
#
#          [[0.68425244, 0.6875613 , 0.6216299 ],
#           [0.7012868 , 0.7043505 , 0.6347426 ],
#           [0.709375  , 0.70643383, 0.6298407 ],
#           ...,
#           [0.76875   , 0.7726716 , 0.78835785],
#           [0.6874387 , 0.6874387 , 0.7325368 ],
#           [0.6782476 , 0.69099265, 0.73737746]],
#
#          [[0.6985294 , 0.6764706 , 0.6161765 ],
#           [0.69417894, 0.68780637, 0.62947303],
#           [0.69172794, 0.7       , 0.6438113 ],
#           ...,
#           [0.7545956 , 0.77028185, 0.77432597],
#           [0.7104167 , 0.7108456 , 0.7477941 ],
#           [0.6848652 , 0.6891544 , 0.7463235 ]],
#
#          ...,
#
#          [[0.40784314, 0.28786764, 0.28020832],
#           [0.41127452, 0.27781862, 0.27493873],
#           [0.40870097, 0.2735294 , 0.2783701 ],
#           ...,
#           [0.82506126, 0.5035539 , 0.51709557],
#           [0.75030637, 0.5582108 , 0.54987746],
#           [0.63915443, 0.56145835, 0.5441789 ]],
#
#          [[0.3947304 , 0.2748162 , 0.28639707],
#           [0.38278186, 0.2637255 , 0.27248776],
#           [0.3814338 , 0.259375  , 0.27800244],
#           ...,
#           [0.9273897 , 0.42352942, 0.44503677],
#           [0.91072303, 0.46813726, 0.49258578],
#           [0.8240809 , 0.51305145, 0.5242034 ]],
#
#          [[0.3538603 , 0.25857842, 0.27628675],
#           [0.35104167, 0.26966912, 0.27653188],
#           [0.35398284, 0.26832107, 0.27732843],
#           ...,
#           [0.9551471 , 0.5113358 , 0.5296569 ],
#           [0.9474878 , 0.46666667, 0.47389707],
#           [0.93419117, 0.453799  , 0.46439952]]],
#
#
#         [[[0.59160537, 0.5837622 , 0.5876838 ],
#           [0.5915441 , 0.5833333 , 0.5872549 ],
#           [0.5939338 , 0.5816789 , 0.5949142 ],
#           ...,
#           [0.58431375, 0.5803922 , 0.6       ],
#           [0.5791054 , 0.578799  , 0.58756125],
#           [0.5891544 , 0.5824142 , 0.59362745]],
#
#          [[0.59460783, 0.59068626, 0.5828431 ],
#           [0.6044118 , 0.5887255 , 0.5926471 ],
#           [0.60294116, 0.5833333 , 0.5990196 ],
#           ...,
#           [0.58958334, 0.58860296, 0.5969363 ],
#           [0.58480394, 0.5846814 , 0.59160537],
#           [0.5930147 , 0.5881128 , 0.59546566]],
#
#          [[0.5926471 , 0.5887255 , 0.5808824 ],
#           [0.59068626, 0.58186275, 0.5857843 ],
#           [0.6039216 , 0.58431375, 0.6       ],
#           ...,
#           [0.58523285, 0.5773897 , 0.5813113 ],
#           [0.58621323, 0.58523285, 0.58572304],
#           [0.59460783, 0.5918505 , 0.5878676 ]],
#
#          ...,
#
#          [[0.60134804, 0.6170343 , 0.6209559 ],
#           [0.58817405, 0.61170346, 0.61170346],
#           [0.5838235 , 0.6073529 , 0.5995098 ],
#           ...,
#           [0.25784314, 0.05784314, 0.05202206],
#           [0.25582108, 0.05974265, 0.03229167],
#           [0.26354167, 0.0596201 , 0.04068628]],
#
#          [[0.5864583 , 0.6021446 , 0.6034926 ],
#           [0.5877451 , 0.6044118 , 0.60085785],
#           [0.5773897 , 0.6009191 , 0.593076  ],
#           ...,
#           [0.25441176, 0.06127451, 0.04129902],
#           [0.25539216, 0.05631128, 0.03786765],
#           [0.2509804 , 0.053125  , 0.04546569]],
#
#          [[0.58253676, 0.5951593 , 0.5912377 ],
#           [0.5723652 , 0.59117645, 0.5797181 ],
#           [0.5686275 , 0.5995098 , 0.58137256],
#           ...,
#           [0.2529412 , 0.06139706, 0.03854167],
#           [0.24491422, 0.0533701 , 0.03523284],
#           [0.25637254, 0.06819853, 0.04852941]]],
#
#
#         [[[0.96911764, 0.9990809 , 0.99460787],
#           [0.97745097, 1.        , 0.99693626],
#           [0.9816789 , 0.9973652 , 0.9934436 ],
#           ...,
#           [0.8938113 , 0.9282476 , 0.9678309 ],
#           [0.9254902 , 0.94031864, 0.96746325],
#           [0.9346201 , 0.93670344, 0.9533088 ]],
#
#          [[0.9831495 , 0.99785537, 0.9939338 ],
#           [0.9866422 , 1.        , 0.9965686 ],
#           [0.99264705, 1.        , 0.9965686 ],
#           ...,
#           [0.89166665, 0.9338235 , 0.95686275],
#           [0.9209559 , 0.95140934, 0.9646446 ],
#           [0.92579657, 0.9429534 , 0.9547181 ]],
#
#          [[0.9911765 , 0.9941176 , 0.99264705],
#           [0.9886642 , 0.99650735, 0.9925858 ],
#           [0.9843137 , 1.        , 0.99607843],
#           ...,
#           [0.91672796, 0.9303309 , 0.9490196 ],
#           [0.9180147 , 0.93762255, 0.9494485 ],
#           [0.9283701 , 0.9494485 , 0.9568015 ]],
#
#          ...,
#
#          [[0.45324755, 0.21305147, 0.21550246],
#           [0.45778185, 0.2305147 , 0.22248775],
#           [0.43192402, 0.21623774, 0.20447303],
#           ...,
#           [0.45992646, 0.20153186, 0.2045956 ],
#           [0.43927696, 0.19816177, 0.1956495 ],
#           [0.42561275, 0.19031863, 0.18786764]],
#
#          [[0.45637256, 0.21685049, 0.21354167],
#           [0.4452206 , 0.21776961, 0.21335784],
#           [0.43933824, 0.22064951, 0.22218138],
#           ...,
#           [0.44276962, 0.1810049 , 0.2069853 ],
#           [0.44828433, 0.19466911, 0.22365196],
#           [0.40900734, 0.17518382, 0.18596813]],
#
#          [[0.45974264, 0.2038603 , 0.21023284],
#           [0.44705883, 0.20870098, 0.21930148],
#           [0.43780637, 0.20116422, 0.22242647],
#           ...,
#           [0.4488358 , 0.18982843, 0.20177697],
#           [0.46691176, 0.20692402, 0.24405637],
#           [0.4088848 , 0.1740196 , 0.18627451]]]], dtype=float32),
#  (array([[1],
#          [1],
#          [1],
#          [1],
#          [1],
#          [1],
#          [1],
#          [1]], dtype=uint8),
#   array([[0.0768 , 0.2917 , 0.665  , 0.935  ],
#          [0.2705 , 0.2603 , 0.7603 , 0.634  ],
#          [0.12286, 0.1332 , 0.802  , 0.912  ],
#          [0.1328 , 0.239  , 0.8545 , 1.     ],
#          [0.305  , 0.01628, 1.     , 0.8135 ],
#          [0.0911 , 0.1218 , 0.802  , 0.8457 ],
#          [0.397  , 0.1091 , 1.     , 0.711  ],
#          [0.06042, 0.01407, 0.881  , 0.8115 ]], dtype=float16)))

# %% [markdown]
# ### 7.3 View Images and Annotations

# %%
data_samples = train.as_numpy_iterator()

# %%
res = data_samples.next()

# %%
fig, ax = plt.subplots(ncols=4, figsize=(20, 20))

for idx in range(4):
    # Extract image and coordinates
    sample_image = res[0][idx].copy()  # Create a writable copy of the image
    sample_coords = res[1][1][idx]

    # Draw rectangle on the image
    cv2.rectangle(
        sample_image,
        tuple(np.multiply(sample_coords[:2], [120, 120]).astype(int)),  # Top-left corner
        tuple(np.multiply(sample_coords[2:], [120, 120]).astype(int)),  # Bottom-right corner
        (255, 0, 0),  # Color (Blue in BGR)
        2  # Thickness
    )

    # Display the image
    ax[idx].imshow(sample_image)

plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..255.0].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..255.0].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..255.0].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..255.0].

# %% [markdown]
# # 8. Build Deep Learning using the Functional API

# %% [markdown]
# ### 8.1 Import Layers and Base Network

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, Dense, GlobalMaxPooling2D
from tensorflow.keras.applications import VGG16

# %% [markdown]
# ### 8.2 Download VGG16

# %%
vgg = VGG16(include_top=False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step

# %%
vgg.summary()
# Out:
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, None, None, 3)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, None, None, 64) │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, None, None, 64) │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, None, None, 64) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, None, None,     │        73,856 │
# │                                 │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, None, None,     │       147,584 │
# │                                 │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, None, None,     │             0 │
# │                                 │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, None, None,     │       295,168 │
# │                                 │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, None, None,     │       590,080 │
# │                                 │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, None, None,     │       590,080 │
# │                                 │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, None, None,     │             0 │
# │                                 │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, None, None,     │     1,180,160 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, None, None,     │             0 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, None, None,     │             0 │
# │                                 │ 512)                   │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,714,688 (56.13 MB)
#  Trainable params: 14,714,688 (56.13 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### 8.3 Build instance of Network

# %%
def build_model():
    input_layer = Input(shape=(120,120,3))

    vgg = VGG16(include_top=False)(input_layer)

    # Classification Model
    f1 = GlobalMaxPooling2D()(vgg)
    class1 = Dense(2048, activation='relu')(f1)
    class2 = Dense(1, activation='sigmoid')(class1)

    # Bounding box model
    f2 = GlobalMaxPooling2D()(vgg)
    regress1 = Dense(2048, activation='relu')(f2)
    regress2 = Dense(4, activation='sigmoid')(regress1)

    facetracker = Model(inputs=input_layer, outputs=[class2, regress2])
    return facetracker

# %% [markdown]
# ### 8.4 Test out Neural Network

# %%
facetracker = build_model()

# %%
facetracker.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 120, 120,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ vgg16 (Functional)  │ (None, 3, 3, 512) │ 14,714,688 │ input_layer_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 512)       │          0 │ vgg16[0][0]       │
# │ (GlobalMaxPooling2… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 512)       │          0 │ vgg16[0][0]       │
# │ (GlobalMaxPooling2… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 2048)      │  1,050,624 │ global_max_pooli… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 2048)      │  1,050,624 │ global_max_pooli… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1)         │      2,049 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 4)         │      8,196 │ dense_2[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 16,826,181 (64.19 MB)
#  Trainable params: 16,826,181 (64.19 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
X, y = train.as_numpy_iterator().next()

# %%
y
# Out:
# (array([[1],
#         [1],
#         [1],
#         [1],
#         [1],
#         [1],
#         [1],
#         [1]], dtype=uint8),
#  array([[0.4404 , 0.2363 , 0.783  , 0.709  ],
#         [0.     , 0.2068 , 0.383  , 0.7817 ],
#         [0.1991 , 0.1777 , 0.613  , 0.737  ],
#         [0.776  , 0.54   , 0.78   , 0.5435 ],
#         [0.     , 0.09973, 0.266  , 0.6284 ],
#         [0.     , 0.05804, 0.3215 , 0.666  ],
#         [0.4216 , 0.1937 , 0.7705 , 0.7065 ],
#         [0.1973 , 0.2588 , 0.6577 , 0.978  ]], dtype=float16))

# %%
X.shape
# Out:
# (8, 120, 120, 3)

# %%
classes, coords = facetracker.predict(X)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step

# %%
classes, coords

# %%
y[1]

# %% [markdown]
# # 9. Define Losses and Optimizers

# %% [markdown]
# ### 9.1 Define Optimizer and LR

# %%
len(train)
# Out:
# 488

# %%
batches_per_epoch = len(train)

# %%
opt = tf.keras.optimizers.Adam(learning_rate=0.0001)

# %% [markdown]
# ### 9.2 Create Localization Loss and Classification Loss

# %%
def localization_loss(y_true, yhat):
    delta_coord = tf.reduce_sum(tf.square(y_true[:,:2] - yhat[:,:2]))

    h_true = y_true[:,3] - y_true[:,1]
    w_true = y_true[:,2] - y_true[:,0]

    h_pred = yhat[:,3] - yhat[:,1]
    w_pred = yhat[:,2] - yhat[:,0]

    delta_size = tf.reduce_sum(tf.square(w_true - w_pred) + tf.square(h_true-h_pred))

    return delta_coord + delta_size

# %%
classloss = tf.keras.losses.BinaryCrossentropy()
regressloss = localization_loss

# %% [markdown]
# ### 9.3 Test out Loss Metrics

# %%
localization_loss(y[1], coords)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-3797ae956af6> in <cell line: 0>()
# ----> 1 localization_loss(y[1], coords)
#
# NameError: name 'y' is not defined

# %%
classloss(y[0], classes)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.5994316935539246>

# %%
regressloss(y[1], coords)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=9.338335037231445>

# %% [markdown]
# # 10. Train Neural Network

# %% [markdown]
# ### 10.1 Create Custom Model Class

# %%
from tensorflow.keras import saving
from tensorflow.keras.models import Model

@saving.register_keras_serializable()
class FaceTracker(Model):
    def __init__(self, facetracker, **kwargs):
        super().__init__(**kwargs)
        self.model = facetracker

    def compile(self, opt, classloss, localizationloss, **kwargs):
        super().compile(**kwargs)
        self.closs = classloss
        self.lloss = localizationloss
        self.opt = opt

    def train_step(self, batch, **kwargs):
        X, y = batch
        y[0].set_shape([None, 1])

        with tf.GradientTape() as tape:
            classes, coords = self.model(X, training=True)
            y0 = tf.cast(y[0], tf.float32)
            batch_classloss = self.closs(y0, classes)
            batch_localizationloss = self.lloss(tf.cast(y[1], tf.float32), coords)

            total_loss = batch_localizationloss + 0.5 * batch_classloss
            grad = tape.gradient(total_loss, self.model.trainable_variables)

        self.opt.apply_gradients(zip(grad, self.model.trainable_variables))

        return {"total_loss": total_loss, "class_loss": batch_classloss, "regress_loss": batch_localizationloss}

    def test_step(self, batch, **kwargs):
        X, y = batch
        y[0].set_shape([None, 1])

        classes, coords = self.model(X, training=False)
        y0 = tf.cast(y[0], tf.float32)
        batch_classloss = self.closs(y0, classes)
        batch_localizationloss = self.lloss(tf.cast(y[1], tf.float32), coords)
        total_loss = batch_localizationloss + 0.5 * batch_classloss

        return {"total_loss": total_loss, "class_loss": batch_classloss, "regress_loss": batch_localizationloss}

    def call(self, X, **kwargs):
        return self.model(X, **kwargs)

    def get_config(self):
        # Ensure facetracker is serialized properly
        config = super().get_config()
        config.update({"facetracker": saving.serialize_keras_object(self.model)})
        return config

    @classmethod
    def from_config(cls, config):
        facetracker = saving.deserialize_keras_object(config.pop("facetracker"))
        return cls(facetracker=facetracker, **config)

# %%
model = FaceTracker(facetracker)

# %%
model.compile(opt, classloss, regressloss)

# %% [markdown]
# ### 10.2 Train

# %%
logdir='logs'

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
hist = model.fit(train, epochs=40, validation_data=val, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/40
# 473/473 ━━━━━━━━━━━━━━━━━━━━
40
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 45s 83ms/step - class_loss: 0.0044 - regress_loss: 0.0154 - total_loss: 0.0176 - val_class_loss: 2.6308e-07 - val_regress_loss: 0.6413 - val_total_loss: 0.6413
# Epoch 33/40
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 82s 83ms/step - class_loss: 0.0067 - regress_loss: 0.0098 - total_loss: 0.0131 - val_class_loss: 1.8899e-05 - val_regress_loss: 2.1012 - val_total_loss: 2.1012
# Epoch 34/40
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 46s 82ms/step - class_loss: 0.0081 - regress_loss: 0.0088 - total_loss: 0.0129 - val_class_loss: 1.0061e-05 - val_regress_loss: 0.5773 - val_total_loss: 0.5773
# Epoch 35/40
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 46s 83ms/step - class_loss: 0.0081 - regress_loss: 0.0079 - total_loss: 0.0119 - val_class_loss: 4.9513e-06 - val_regress_loss: 0.7484 - val_total_loss: 0.7484
# Epoch 36/40
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 47s 87ms/step - class_loss: 0.0126 - regress_loss: 0.0401 - total_loss: 0.0464 - val_class_loss: 3.4632 - val_regress_loss: 1.9099 - val_total_loss: 3.6415
# Epoch 37/40
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 80s 83ms/step - class_loss: 0.0018 - regress_loss: 0.0135 - total_loss: 0.0144 - val_class_loss: 3.1500e-06 - val_regress_loss: 0.5650 - val_total_loss: 0.5650
# Epoch 38/40
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 45s 82ms/step - class_loss: 0.0233 - regress_loss: 0.0266 - total_loss: 0.0383 - val_class_loss: 4.2536 - val_regress_loss: 2.7217 - val_total_loss: 4.8485
# Epoch 39/40
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 46s 83ms/step - class_loss: 0.0015 - regress_loss: 0.0064 - total_loss: 0.0072 - val_class_loss: 3.0697 - val_regress_loss: 1.1501 - val_total_loss: 2.6849
# Epoch 40/40
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 82s 82ms/step - class_loss: 9.7346e-05 - regress_loss: 0.0025 - total_loss: 0.0025 - val_class_loss: 6.3870e-06 - val_regress_loss: 1.8074 - val_total_loss: 1.8074

# %%
print("y[0] shape:", y[0].shape)
print("classes shape:", classes.shape)
# Out:
# y[0] shape: (8, 1)
# classes shape: (8, 1)

# %% [markdown]
# ### 11.2 Save the Model

# %%
model.save('drive/MyDrive/Face Detection Model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from tensorflow.keras.models import load_model

# Load model without compiling
fashgan = load_model(
    '/content/drive/MyDrive/Face Detection model.h5',
    custom_objects={
        'FaceTracker': FaceTracker,
        'classloss': classloss,
        'regressloss': regressloss  # Ensure this function is defined
    },
    compile=False  # Disable automatic compilation
)

# %% [markdown]
# ### 10.3 Plot Performance

# %%
hist.history
# Out:
# {'class_loss': [7.266603461175691e-06,
#   1.3977174830870354e-06,
#   1.2930765933560906e-06,
#   3.337306395678752e-07,
#   3.4841065144064487e-07,
#   1.0534077432566846e-07,
#   2.9455669903200032e-08,
#   1.2741821819872712e-07,
#   2.2283464318206825e-07,
#   5.3488665940903957e-08,
#   6.355324444484722e-08,
#   1.0141732786905777e-08,
#   2.057685719591973e-07,
#   1.2211044619903078e-08,
#   2.942608468003982e-08,
#   1.0095719815694792e-08,
#   7.375006383369964e-09,
#   1.5429555411117235e-09,
#   2.3304446372662824e-08,
#   7.58655449573098e-09,
#   1.047564257561362e-09,
#   2.2703034119331278e-08,
#   1.247671477244694e-08,
#   1.261837745403227e-08,
#   7.231579779443109e-09,
#   5.351419307686456e-09,
#   3.4630840417548825e-09,
#   9.392547184461364e-09,
#   3.3246552733068313e-10,
#   8.16900019851019e-11,
#   7.717840588838953e-09,
#   3.366680934036026e-09,
#   3.5741923309906554e-10,
#   3.477299559406788e-09,
#   4.6319062474431405e-10,
#   6.82157941245265e-11,
#   5.021313920217096e-10,
#   2.6948916431734915e-09,
#   3.006166204855276e-09,
#   3.560867573026982e-11,
#   2.25125626474032e-10,
#   2.4709394530475493e-09,
#   4.1448017240597324e-10],
#  'val_regress_loss': [0.315712571144104,
#   0.4050294756889343,
#   0.48825928568840027,
#   0.36038434505462646,
#   0.23294559121131897,
#   0.4918936491012573,
#   0.6435972452163696,
#   0.32252442836761475,
#   0.25439193844795227,
#   0.21250388026237488,
#   0.6161689758300781,
#   0.3500475585460663,
#   0.9249390363693237,
#   0.33742254972457886,
#   0.6560368537902832,
#   0.68993079662323,
#   0.23822611570358276,
#   0.22806432843208313,
#   0.24006444215774536,
#   0.38834843039512634,
#   0.31045931577682495,
#   0.5092970132827759,
#   0.6401252746582031,
#   0.06102884188294411,
#   0.21879366040229797,
#   0.6082049608230591,
#   0.2449166178703308,
#   0.36412015557289124,
#   0.34516414999961853,
#   0.27761441469192505,
#   0.23184943199157715,
#   0.5118429660797119,
#   0.26466935873031616,
#   0.41150355339050293,
#   0.4182277321815491,
#   0.3004184663295746,
#   0.15200448036193848,
#   0.36582016944885254,
#   0.35580480098724365,
#   0.4502498507499695],
#  'val_total_loss': [0.315715491771698,
#   0.4050295650959015,
#   0.48825934529304504,
#   0.36038437485694885,
#   0.23294563591480255,
#   0.4918936491012573,
#   0.6435972452163696,
#   0.32252445816993713,
#   0.25439193844795227,
#   0.21250388026237488,
#   0.6161690354347229,
#   0.3500475585460663,
#   0.9249390363693237,
#   0.33742254972457886,
#   0.6560368537902832,
#   0.68993079662323,
#   0.23822611570358276,
#   0.22806432843208313,
#   0.24006444215774536,
#   0.38834843039512634,
#   0.31045931577682495,
#   0.5092970132827759,
#   0.6401252746582031,
#   0.06102884188294411,
#   0.21879366040229797,
#   0.6082049608230591,
#   0.2449166178703308,
#   0.36412015557289124,
#   0.34516414999961853,
#   0.27761441469192505,
#   0.23184943199157715,
#   0.5118429660797119,
#   0.26466935873031616,
#   0.41150355339050293,
#   0.4182277321815491,
#   0.3004184663295746,
#   0.15200448036193848,
#   0.36582016944885254,
#   0.35580480098724365,
#   0.4502498507499695]}

# %% [markdown]
# # 11. Make Predictions

# %% [markdown]
# ### 11.1 Make Predictions on Test Set

# %%
test_data = test.as_numpy_iterator()

# %%
test_sample = test_data.next()

# %%
yhat = facetracker.predict(test_sample[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step

# %%
fig, ax = plt.subplots(ncols=4, figsize=(20,20))
for idx in range(4):
    sample_image = test_sample[0][idx].copy()
    sample_coords = yhat[1][idx]

    if yhat[0][idx] > 0.9:
        cv2.rectangle(sample_image,
                      tuple(np.multiply(sample_coords[:2], [120,120]).astype(int)),
                      tuple(np.multiply(sample_coords[2:], [120,120]).astype(int)),
                            (255,0,0), 2)

    ax[idx].imshow(sample_image)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..255.0].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..255.0].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..255.0].
